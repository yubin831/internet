# %% [markdown]
# <a href="https://colab.research.google.com/github/yubin831/internet/blob/main/accident.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = 'http://apis.data.go.kr/B552061/AccidentDeath/getRestTrafficAccidentDeath'
params ={'serviceKey' : '2b/onU57EYorggOcarymOCuTveOhY03gg7OGSbLhNRNRir/5bCzFwAuEn2cLlAre3uILe4CJeZV3jqSmnLWaHg==', 'searchYear' : '2014', 'siDo' : '1100', 'guGun' : '1117', 'type' : 'xml', 'numOfRows' : '10', 'pageNo' : '1' }

response = requests.get(url, params=params)
print(response.content.decode('utf8'))
# Out:
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL_CODE</resultMsg>
#     </header>
#     <body>
#         <items>
#             <item>
#                 <acc_year>2014</acc_year>
#                 <occrrnc_dt>2014010605</occrrnc_dt>
#                 <dght_cd>2</dght_cd>
#                 <occrrnc_day_cd>2</occrrnc_day_cd>
#                 <dth_dnv_cnt>1</dth_dnv_cnt>
#                 <injpsn_cnt>1</injpsn_cnt>
#                 <se_dnv_cnt>0</se_dnv_cnt>
#                 <sl_dnv_cnt>0</sl_dnv_cnt>
#                 <wnd_dnv_cnt>0</wnd_dnv_cnt>
#                 <occrrnc_lc_sido_cd>1100</occrrnc_lc_sido_cd>
#                 <occrrnc_lc_sgg_cd>1117</occrrnc_lc_sgg_cd>
#                 <acc_ty_lclas_cd>01</acc_ty_lclas_cd>
#                 <acc_ty_mlsfc_cd>15</acc_ty_mlsfc_cd>
#                 <acc_ty_cd>05</acc_ty_cd>
#                 <aslt_vtr_cd>05 </aslt_vtr_cd>
#                 <road_frm_lclas_cd>02</road_frm_lclas_cd>
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.content.decode('utf8'), features="xml")

# %%
soup.find_all('occrrnc_dt')
# Out:
# [<occrrnc_dt>2014010605</occrrnc_dt>,
#  <occrrnc_dt>2014010704</occrrnc_dt>,
#  <occrrnc_dt>2014022715</occrrnc_dt>,
#  <occrrnc_dt>2014033105</occrrnc_dt>,
#  <occrrnc_dt>2014042603</occrrnc_dt>,
#  <occrrnc_dt>2014060212</occrrnc_dt>,
#  <occrrnc_dt>2014070203</occrrnc_dt>,
#  <occrrnc_dt>2014082813</occrrnc_dt>,
#  <occrrnc_dt>2014090921</occrrnc_dt>,
#  <occrrnc_dt>2014091816</occrrnc_dt>]
